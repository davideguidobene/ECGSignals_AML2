# %%
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.model_selection import cross_val_score
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from tslearn.utils import to_time_series_dataset
import biosppy.signals.ecg as ecg
import matplotlib.pyplot as plt
import neurokit2 as nk
import heartpy as hp
from statistics import mean
import functions
from multiprocessing import Pool
from datetime import time
from pandarallel import pandarallel
import functions
import scipy
import math
import pywt
import operator
from functions import *
import itertools
from sklearn.ensemble import ExtraTreesClassifier

# %%
folder = ""
raw = folder + "raw_data/"
x_train = pd.read_csv('x_train_preprocess.csv')
x_test = pd.read_csv('x_test_preprocess.csv')
y_train = pd.read_csv(raw + 'y_train.csv', index_col=['id'])

x_train = x_train.fillna(0)
x_test = x_test.fillna(0)
np.isinf(x_train).values.sum()
# Out:
# 0

# %%
col_name = x_train.columns.to_series()[np.isinf(x_train).any()]
col_name
# Out:
# Series([], dtype: object)

# %%
#anomaly detection with isolation forest with scores
from sklearn.ensemble import IsolationForest
clf = IsolationForest(n_estimators=200, random_state=42)
clf.fit(x_train)
y_pred_train = clf.predict(x_train)
scores = clf.decision_function(x_train)
#count anomalies
anomalies = 0
for i in y_pred_train:
    if i == -1:
        anomalies += 1
print(anomalies)
#remove anomalies
#x_train = x_train[y_pred_train == 1]
#y_train = y_train[y_pred_train == 1]
# Out:
# 167

# %%
scores = pd.DataFrame(scores , columns = ['scores'])
#print scores higher than 0.7
max(scores['scores'])
# Out:
# 0.1532576439717614

# %%
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5117 entries, 0 to 5116
# Columns: 1009 entries, Unnamed: 0 to nk_feat_387
# dtypes: float64(1008), int64(1)
# memory usage: 39.4 MB

# %%
#save feature name
feature_name = x_train.columns

# %%
selector = SelectKBest(score_func=f_classif, k=925)
selector.fit(np.array(x_train), np.array(y_train).squeeze())
cols = selector.get_support(indices=True)
# Out:
# /home/francescog/Scaricati/AML_Pr_2/venv/lib/python3.8/site-packages/sklearn/feature_selection/_univariate_selection.py:110: UserWarning: Features [72] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx, UserWarning)

# %%
x_train= x_train.iloc[:,cols]
x_test = x_test.iloc[:,cols]

# %%
#scale data
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
#random forest
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(n_estimators=300, random_state=0)

# %%
#cross validation score
scores = cross_val_score(clf, x_train, np.ravel(y_train), cv=10, scoring='f1_micro',n_jobs=-1)
print(scores.mean())
print(scores.std())
#0.6880920529598826 / 0.01306019561569018 MinMaxScaler
#0.6912193462573386 / 0.011284110708011923 new preprocessing
#0.6984512597847358 / 0.012100579167071735 new new preprocessing
#0.6990349039872799 / 0.009122000817677589 378 nk feat
#0.7736909093688845 / 0.01017577556042029 1009 feat
#0.7791619526663405 / 0.008659228728196107 950 feat
#0.7758412579500978 / 0.01054161411455059 850 feat
#0.7774033757338552 / 0.011964939066628696 900 feat
#0.7762341762475538 / 0.00917907789442495 975 feat
#0.7758378180039138 / 0.016074265927511638 925 feat
# Out:
# 0.7758378180039138
# 0.016074265927511638

# %%
clf.fit(x_train, np.ravel(y_train))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [13], line 1
# ----> 1 clf.fit(x_train, np.ravel(y_train))
#
# File ~/Scaricati/AML_Pr_2/venv/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:476, in BaseForest.fit(self, X, y, sample_weight)
#     465 trees = [
#     466     self._make_estimator(append=False, random_state=random_state)
#     467     for i in range(n_more_estimators)
#     468 ]
#     470 # Parallel loop: we prefer the threading backend as the Cython code
#     471 # for fitting the trees is internally releasing the Python GIL
#     472 # making threading more efficient than multiprocessing in
#     473 # that case. However, for joblib 0.12+ we respect any
#     474 # parallel_backend contexts set at a higher level,
#     475 # since correctness does not rely on using threads.
# --> 476 trees = Parallel(
#     477     n_jobs=self.n_jobs,
#     478     verbose=self.verbose,
#     479     prefer="threads",
#     480 )(
#     481     delayed(_parallel_build_trees)(
#     482         t,
#     483         self.bootstrap,
#     484         X,
#     485         y,
#     486         sample_weight,
#     487         i,
#     488         len(trees),
#     489         verbose=self.verbose,
#     490         class_weight=self.class_weight,
#     491         n_samples_bootstrap=n_samples_bootstrap,
#     492     )
#     493     for i, t in enumerate(trees)
#     494 )
#     496 # Collect newly grown trees
#     497 self.estimators_.extend(trees)
#
# File ~/Scaricati/AML_Pr_2/venv/lib/python3.8/site-packages/joblib/parallel.py:1088, in Parallel.__call__(self, iterable)
#    1085 if self.dispatch_one_batch(iterator):
#    1086     self._iterating = self._original_iterator is not None
# -> 1088 while self.dispatch_one_batch(iterator):
#    1089     pass
#    1091 if pre_dispatch == "all" or n_jobs == 1:
#    1092     # The iterable was consumed all at once by the above for loop.
#    1093     # No need to wait for async callbacks to trigger to
#    1094     # consumption.
#
# File ~/Scaricati/AML_Pr_2/venv/lib/python3.8/site-packages/joblib/parallel.py:901, in Parallel.dispatch_one_batch(self, iterator)
#     899     return False
#     900 else:
# --> 901     self._dispatch(tasks)
#     902     return True
#
# File ~/Scaricati/AML_Pr_2/venv/lib/python3.8/site-packages/joblib/parallel.py:819, in Parallel._dispatch(self, batch)
#     817 with self._lock:
#     818     job_idx = len(self._jobs)
# --> 819     job = self._backend.apply_async(batch, callback=cb)
#     820     # A job can complete so quickly than its callback is
#     821     # called before we get here, causing self._jobs to
#     822     # grow. To ensure correct results ordering, .insert is
#     823     # used (rather than .append) in the following line
#     824     self._jobs.insert(job_idx, job)
#
# File ~/Scaricati/AML_Pr_2/venv/lib/python3.8/site-packages/joblib/_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File ~/Scaricati/AML_Pr_2/venv/lib/python3.8/site-packages/joblib/_parallel_backends.py:597, in ImmediateResult.__init__(self, batch)
#     594 def __init__(self, batch):
#     595     # Don't delay the application, to avoid keeping the input
#     596     # arguments in memory
# --> 597     self.results = batch()
#
# File ~/Scaricati/AML_Pr_2/venv/lib/python3.8/site-packages/joblib/parallel.py:288, in BatchedCalls.__call__(self)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File ~/Scaricati/AML_Pr_2/venv/lib/python3.8/site-packages/joblib/parallel.py:288, in <listcomp>(.0)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File ~/Scaricati/AML_Pr_2/venv/lib/python3.8/site-packages/sklearn/utils/fixes.py:117, in _FuncWrapper.__call__(self, *args, **kwargs)
#     115 def __call__(self, *args, **kwargs):
#     116     with config_context(**self.config):
# --> 117         return self.function(*args, **kwargs)
#
# File ~/Scaricati/AML_Pr_2/venv/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:189, in _parallel_build_trees(tree, bootstrap, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap)
#     186     elif class_weight == "balanced_subsample":
#     187         curr_sample_weight *= compute_sample_weight("balanced", y, indices=indices)
# --> 189     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#     190 else:
#     191     tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#
# File ~/Scaricati/AML_Pr_2/venv/lib/python3.8/site-packages/sklearn/tree/_classes.py:969, in DecisionTreeClassifier.fit(self, X, y, sample_weight, check_input)
#     939 def fit(self, X, y, sample_weight=None, check_input=True):
#     940     """Build a decision tree classifier from the training set (X, y).
#     941
#     942     Parameters
#    (...)
#     966         Fitted estimator.
#     967     """
# --> 969     super().fit(
#     970         X,
#     971         y,
#     972         sample_weight=sample_weight,
#     973         check_input=check_input,
#     974     )
#     975     return self
#
# File ~/Scaricati/AML_Pr_2/venv/lib/python3.8/site-packages/sklearn/tree/_classes.py:458, in BaseDecisionTree.fit(self, X, y, sample_weight, check_input)
#     447 else:
#     448     builder = BestFirstTreeBuilder(
#     449         splitter,
#     450         min_samples_split,
#    (...)
#     455         self.min_impurity_decrease,
#     456     )
# --> 458 builder.build(self.tree_, X, y, sample_weight)
#     460 if self.n_outputs_ == 1 and is_classifier(self):
#     461     self.n_classes_ = self.n_classes_[0]
#
# KeyboardInterrupt:

# %%
#feature importance
importances = clf.feature_importances_
indices = np.argsort(importances)[::-1]
# Print the feature ranking
print("Feature ranking:")
for f in range(x_train.shape[1]):
    print("%d. feature %s (%f)" % (f + 1, feature_name[indices[f]], importances[indices[f]]))
# Out:
# Feature ranking:
# 1. feature nk_feat_195 (0.015164)
# 2. feature nni_min (0.014657)
# 3. feature nni_range (0.012763)
# 4. feature nk_feat_196 (0.012638)
# 5. feature nni_var (0.012339)
# 6. feature heart_rate_iqr (0.011054)
# 7. feature nni_std (0.010856)
# 8. feature heart_rate_median (0.010673)
# 9. feature nk_feat_193 (0.010599)
# 10. feature nk_feat_199 (0.010522)
# 11. feature heart_rate_mean (0.010487)
# 12. feature nni_iqr (0.009825)
# 13. feature nni_median (0.009639)
# 14. feature heart_rate_range (0.009430)
# 15. feature nk_feat_192 (0.009258)
# 16. feature heart_rate_var (0.008832)
# 17. feature nk_feat_198 (0.008213)
# 18. feature heart_rate_std (0.008081)
# 19. feature nk_feat_194 (0.006854)
# 20. feature nk_feat_191 (0.006831)
# 21. feature nni_max (0.006638)
# 22. feature nni_mean (0.006467)
# 23. feature nk_feat_3 (0.006268)
# 24. feature heart_rate_max (0.005906)
# 25. feature heart_rate_min (0.004932)
# 26. feature nk_feat_197 (0.004784)
# 27. feature nni_skew (0.004677)
# 28. feature nk_feat_4 (0.003575)
# 29. feature fft_median_0 (0.003536)
# 30. feature nni_kurtosis (0.003355)
# 31. feature heart_rate_skew (0.003221)
# 32. feature fft_mean_0 (0.003151)
# 33. feature heart_rate_kurtosis (0.003107)
# 34. feature nk_feat_5 (0.003000)
# 35. feature nk_feat_184 (0.002646)
# 36. feature nk_feat_38 (0.002441)
# 37. feature nk_feat_155 (0.002395)
# 38. feature nk_feat_34 (0.002310)
# 39. feature nk_feat_95 (0.002306)
# 40. feature nk_feat_168 (0.002290)
# 41. feature nk_feat_156 (0.002251)
# 42. feature nk_feat_158 (0.002196)
# 43. feature nk_feat_8 (0.002180)
# 44. feature nk_feat_41 (0.002138)
# 45. feature nk_feat_6 (0.002065)
# 46. feature nk_feat_169 (0.002036)
# 47. feature fft_min_1 (0.002011)
# 48. feature mu_41 (0.001998)
# 49. feature nk_feat_35 (0.001971)
# 50. feature mu_70 (0.001962)
# 51. feature mu_43 (0.001917)
# 52. feature nk_feat_185 (0.001891)
# 53. feature nk_feat_28 (0.001882)
# 54. feature nk_feat_134 (0.001854)
# 55. feature nk_feat_9 (0.001851)
# 56. feature mu_76 (0.001803)
# 57. feature mu_75 (0.001786)
# 58. feature mu_71 (0.001761)
# 59. feature nk_feat_25 (0.001747)
# 60. feature mu_73 (0.001718)
# 61. feature mu_42 (0.001709)
# 62. feature mu_72 (0.001705)
# 63. feature median_79 (0.001696)
# 64. feature nk_feat_103 (0.001677)
# 65. feature median_70 (0.001652)
# 66. feature median_44 (0.001634)
# 67. feature nk_feat_36 (0.001616)
# 68. feature nk_feat_42 (0.001614)
# 69. feature nk_feat_32 (0.001609)
# 70. feature nk_feat_100 (0.001605)
# 71. feature nk_feat_7 (0.001596)
# 72. feature nk_feat_104 (0.001593)
# 73. feature fft_median_2 (0.001588)
# 74. feature std_177 (0.001586)
# 75. feature fft_max_1 (0.001581)
# 76. feature nk_feat_133 (0.001579)
# 77. feature nk_feat_127 (0.001573)
# 78. feature nk_feat_92 (0.001567)
# 79. feature nk_feat_128 (0.001557)
# 80. feature mu_39 (0.001554)
# 81. feature mu_77 (0.001553)
# 82. feature median_72 (0.001526)
# 83. feature mu_74 (0.001526)
# 84. feature nk_feat_106 (0.001518)
# 85. feature nk_feat_37 (0.001510)
# 86. feature fft_q1_2 (0.001508)
# 87. feature median_71 (0.001504)
# 88. feature nk_feat_84 (0.001504)
# 89. feature mu_45 (0.001501)
# 90. feature nk_feat_89 (0.001499)
# 91. feature nk_feat_126 (0.001482)
# 92. feature median_77 (0.001479)
# 93. feature median_75 (0.001458)
# 94. feature mu_78 (0.001443)
# 95. feature nk_feat_78 (0.001435)
# 96. feature nk_feat_203 (0.001430)
# 97. feature mu_46 (0.001429)
# 98. feature mu_69 (0.001415)
# 99. feature median_74 (0.001415)
# 100. feature median_13 (0.001411)
# 101. feature median_14 (0.001410)
# 102. feature median_80 (0.001406)
# 103. feature fft_q10_1 (0.001405)
# 104. feature std_178 (0.001400)
# 105. feature mu_79 (0.001395)
# 106. feature nk_feat_107 (0.001390)
# 107. feature median_78 (0.001385)
# 108. feature nk_feat_130 (0.001383)
# 109. feature median_43 (0.001375)
# 110. feature median_73 (0.001369)
# 111. feature median_42 (0.001365)
# 112. feature median_69 (0.001357)
# 113. feature nk_feat_98 (0.001350)
# 114. feature median_11 (0.001321)
# 115. feature mu_68 (0.001319)
# 116. feature mu_44 (0.001316)
# 117. feature mu_40 (0.001309)
# 118. feature nk_feat_26 (0.001307)
# 119. feature fft_std_0 (0.001304)
# 120. feature median_46 (0.001298)
# 121. feature nk_feat_120 (0.001298)
# 122. feature median_9 (0.001292)
# 123. feature nk_feat_66 (0.001287)
# 124. feature median_67 (0.001286)
# 125. feature median_41 (0.001285)
# 126. feature median_82 (0.001285)
# 127. feature nk_feat_118 (0.001275)
# 128. feature fft_mean_change_1 (0.001268)
# 129. feature std_176 (0.001260)
# 130. feature nk_feat_105 (0.001257)
# 131. feature nk_feat_200 (0.001248)
# 132. feature nk_feat_109 (0.001247)
# 133. feature median_127 (0.001244)
# 134. feature nk_feat_131 (0.001238)
# 135. feature std_175 (0.001235)
# 136. feature median_45 (0.001235)
# 137. feature median_40 (0.001234)
# 138. feature mu_38 (0.001230)
# 139. feature nk_feat_214 (0.001225)
# 140. feature median_12 (0.001217)
# 141. feature mu_127 (0.001210)
# 142. feature nk_feat_77 (0.001209)
# 143. feature median_39 (0.001207)
# 144. feature nk_feat_96 (0.001205)
# 145. feature nk_feat_119 (0.001204)
# 146. feature mu_37 (0.001203)
# 147. feature std_18 (0.001200)
# 148. feature mu_14 (0.001199)
# 149. feature nk_feat_40 (0.001194)
# 150. feature nk_feat_170 (0.001194)
# 151. feature nk_feat_151 (0.001193)
# 152. feature nk_feat_125 (0.001189)
# 153. feature std_144 (0.001185)
# 154. feature mu_36 (0.001175)
# 155. feature nk_feat_24 (0.001172)
# 156. feature median_10 (0.001170)
# 157. feature mu_178 (0.001167)
# 158. feature nk_feat_121 (0.001163)
# 159. feature Unnamed: 0 (0.001163)
# 160. feature median_76 (0.001161)
# 161. feature mu_12 (0.001157)
# 162. feature mu_8 (0.001156)
# 163. feature fft_q10_2 (0.001152)
# 164. feature mu_60 (0.001152)
# 165. feature median_178 (0.001151)
# 166. feature nk_feat_30 (0.001145)
# 167. feature nk_feat_83 (0.001140)
# 168. feature nk_feat_39 (0.001138)
# 169. feature nk_feat_175 (0.001138)
# 170. feature std_14 (0.001137)
# 171. feature std_22 (0.001128)
# 172. feature nk_feat_142 (0.001122)
# 173. feature nk_feat_74 (0.001120)
# 174. feature nk_feat_110 (0.001118)
# 175. feature nk_feat_162 (0.001114)
# 176. feature median_15 (0.001113)
# 177. feature mu_84 (0.001110)
# 178. feature mu_35 (0.001108)
# 179. feature nk_feat_154 (0.001107)
# 180. feature mu_59 (0.001104)
# 181. feature nk_feat_2 (0.001103)
# 182. feature nk_feat_163 (0.001101)
# 183. feature median_38 (0.001100)
# 184. feature median_179 (0.001098)
# 185. feature median_17 (0.001096)
# 186. feature nk_feat_135 (0.001089)
# 187. feature nk_feat_27 (0.001089)
# 188. feature nk_feat_91 (0.001088)
# 189. feature nk_feat_68 (0.001087)
# 190. feature mu_10 (0.001085)
# 191. feature median_5 (0.001085)
# 192. feature nk_feat_213 (0.001082)
# 193. feature nk_feat_81 (0.001079)
# 194. feature median_47 (0.001079)
# 195. feature nk_feat_150 (0.001075)
# 196. feature nk_feat_108 (0.001073)
# 197. feature nk_feat_205 (0.001072)
# 198. feature mu_67 (0.001068)
# 199. feature std_13 (0.001067)
# 200. feature nk_feat_43 (0.001065)
# 201. feature nk_feat_102 (0.001061)
# 202. feature nk_feat_99 (0.001060)
# 203. feature median_81 (0.001059)
# 204. feature median_175 (0.001057)
# 205. feature nk_feat_174 (0.001057)
# 206. feature std_170 (0.001054)
# 207. feature median_176 (0.001052)
# 208. feature std_65 (0.001052)
# 209. feature nk_feat_44 (0.001051)
# 210. feature nk_feat_94 (0.001048)
# 211. feature fft_skew_2 (0.001045)
# 212. feature median_68 (0.001045)
# 213. feature nk_feat_201 (0.001044)
# 214. feature median_8 (0.001042)
# 215. feature std_153 (0.001041)
# 216. feature nk_feat_122 (0.001040)
# 217. feature std_148 (0.001038)
# 218. feature nk_feat_114 (0.001038)
# 219. feature mu_179 (0.001035)
# 220. feature median_19 (0.001035)
# 221. feature nk_feat_161 (0.001034)
# 222. feature nk_feat_72 (0.001032)
# 223. feature mu_47 (0.001032)
# 224. feature mu_87 (0.001031)
# 225. feature std_64 (0.001029)
# 226. feature median_59 (0.001028)
# 227. feature nk_feat_47 (0.001021)
# 228. feature nk_feat_90 (0.001021)
# 229. feature nk_feat_67 (0.001019)
# 230. feature fft_max_2 (0.001017)
# 231. feature median_61 (0.001015)
# 232. feature median_16 (0.001014)
# 233. feature nk_feat_181 (0.001014)
# 234. feature mu_62 (0.001010)
# 235. feature nk_feat_145 (0.001007)
# 236. feature std_156 (0.001006)
# 237. feature nk_feat_157 (0.001004)
# 238. feature std_157 (0.001004)
# 239. feature mu_83 (0.001002)
# 240. feature nk_feat_116 (0.001001)
# 241. feature median_7 (0.001001)
# 242. feature fft_std_2 (0.000999)
# 243. feature median_58 (0.000999)
# 244. feature std_139 (0.000998)
# 245. feature nk_feat_136 (0.000998)
# 246. feature fft_kurtosis_2 (0.000997)
# 247. feature nk_feat_190 (0.000993)
# 248. feature std_10 (0.000993)
# 249. feature median_48 (0.000993)
# 250. feature nk_feat_189 (0.000993)
# 251. feature fft_q95_3 (0.000990)
# 252. feature std_35 (0.000989)
# 253. feature mu_17 (0.000988)
# 254. feature mu_9 (0.000985)
# 255. feature nk_feat_141 (0.000983)
# 256. feature std_162 (0.000983)
# 257. feature mu_13 (0.000983)
# 258. feature nk_feat_101 (0.000980)
# 259. feature nk_feat_76 (0.000979)
# 260. feature mu_175 (0.000979)
# 261. feature nk_feat_117 (0.000978)
# 262. feature mu_11 (0.000977)
# 263. feature nk_feat_171 (0.000976)
# 264. feature mu_129 (0.000976)
# 265. feature mu_85 (0.000974)
# 266. feature std_76 (0.000972)
# 267. feature fft_min_2 (0.000971)
# 268. feature nk_feat_31 (0.000971)
# 269. feature std_17 (0.000971)
# 270. feature nk_feat_188 (0.000964)
# 271. feature mu_15 (0.000963)
# 272. feature nk_feat_113 (0.000960)
# 273. feature nk_feat_10 (0.000960)
# 274. feature std_55 (0.000959)
# 275. feature std_161 (0.000959)
# 276. feature std_66 (0.000958)
# 277. feature median_34 (0.000956)
# 278. feature nk_feat_186 (0.000956)
# 279. feature std_15 (0.000954)
# 280. feature mu_173 (0.000952)
# 281. feature median_132 (0.000948)
# 282. feature median_60 (0.000947)
# 283. feature median_66 (0.000947)
# 284. feature mu_61 (0.000946)
# 285. feature std_20 (0.000946)
# 286. feature std_63 (0.000944)
# 287. feature nk_feat_15 (0.000942)
# 288. feature nk_feat_132 (0.000942)
# 289. feature std_53 (0.000942)
# 290. feature nk_feat_183 (0.000941)
# 291. feature median_86 (0.000941)
# 292. feature std_155 (0.000939)
# 293. feature std_60 (0.000938)
# 294. feature fft_kurtosis_3 (0.000938)
# 295. feature nk_feat_85 (0.000937)
# 296. feature nk_feat_159 (0.000937)
# 297. feature median_36 (0.000936)
# 298. feature std_141 (0.000936)
# 299. feature std_152 (0.000934)
# 300. feature nk_feat_123 (0.000934)
# 301. feature mu_7 (0.000931)
# 302. feature median_65 (0.000930)
# 303. feature std_27 (0.000930)
# 304. feature fft_iqr_2 (0.000930)
# 305. feature std_140 (0.000929)
# 306. feature nk_feat_71 (0.000928)
# 307. feature nk_feat_65 (0.000927)
# 308. feature mu_81 (0.000927)
# 309. feature std_19 (0.000927)
# 310. feature nk_feat_149 (0.000926)
# 311. feature std_151 (0.000925)
# 312. feature nk_feat_187 (0.000924)
# 313. feature fft_q3_2 (0.000922)
# 314. feature mu_66 (0.000922)
# 315. feature std_159 (0.000920)
# 316. feature std_163 (0.000920)
# 317. feature std_164 (0.000920)
# 318. feature std_173 (0.000919)
# 319. feature nk_feat_69 (0.000916)
# 320. feature nk_feat_224 (0.000915)
# 321. feature std_160 (0.000915)
# 322. feature mu_80 (0.000915)
# 323. feature nk_feat_227 (0.000914)
# 324. feature nk_feat_124 (0.000913)
# 325. feature nk_feat_86 (0.000911)
# 326. feature mu_18 (0.000910)
# 327. feature median_57 (0.000910)
# 328. feature nk_feat_173 (0.000909)
# 329. feature std_1 (0.000909)
# 330. feature nk_feat_111 (0.000909)
# 331. feature mu_176 (0.000909)
# 332. feature nk_feat_79 (0.000905)
# 333. feature std_21 (0.000905)
# 334. feature std_44 (0.000905)
# 335. feature std_52 (0.000904)
# 336. feature std_172 (0.000904)
# 337. feature nk_feat_1 (0.000904)
# 338. feature std_150 (0.000902)
# 339. feature mu_16 (0.000901)
# 340. feature std_133 (0.000900)
# 341. feature nk_feat_88 (0.000898)
# 342. feature median_177 (0.000897)
# 343. feature median_20 (0.000897)
# 344. feature std_142 (0.000896)
# 345. feature nk_feat_160 (0.000896)
# 346. feature nk_feat_182 (0.000893)
# 347. feature nk_feat_219 (0.000892)
# 348. feature nk_feat_220 (0.000892)
# 349. feature nk_feat_55 (0.000891)
# 350. feature median_1 (0.000891)
# 351. feature mu_49 (0.000890)
# 352. feature mu_52 (0.000890)
# 353. feature median_35 (0.000890)
# 354. feature mu_5 (0.000890)
# 355. feature mu_56 (0.000889)
# 356. feature std_23 (0.000888)
# 357. feature std_171 (0.000887)
# 358. feature std_166 (0.000887)
# 359. feature std_42 (0.000886)
# 360. feature fft_median_1 (0.000885)
# 361. feature median_174 (0.000884)
# 362. feature std_51 (0.000884)
# 363. feature std_62 (0.000884)
# 364. feature median_83 (0.000883)
# 365. feature mu_53 (0.000882)
# 366. feature nk_feat_139 (0.000882)
# 367. feature mu_132 (0.000882)
# 368. feature nk_feat_22 (0.000881)
# 369. feature median_173 (0.000879)
# 370. feature median_37 (0.000879)
# 371. feature median_51 (0.000876)
# 372. feature mu_4 (0.000875)
# 373. feature median_62 (0.000875)
# 374. feature median_3 (0.000874)
# 375. feature nk_feat_153 (0.000872)
# 376. feature fft_max_0 (0.000871)
# 377. feature std_71 (0.000870)
# 378. feature nk_feat_179 (0.000870)
# 379. feature nk_feat_216 (0.000869)
# 380. feature nk_feat_164 (0.000868)
# 381. feature nk_feat_70 (0.000868)
# 382. feature fft_mean_3 (0.000868)
# 383. feature nk_feat_206 (0.000866)
# 384. feature nk_feat_18 (0.000865)
# 385. feature mu_48 (0.000865)
# 386. feature std_4 (0.000862)
# 387. feature nk_feat_33 (0.000862)
# 388. feature nk_feat_202 (0.000862)
# 389. feature nk_feat_172 (0.000860)
# 390. feature nk_feat_152 (0.000859)
# 391. feature std_169 (0.000859)
# 392. feature nk_feat_138 (0.000859)
# 393. feature nk_feat_167 (0.000859)
# 394. feature std_84 (0.000859)
# 395. feature nk_feat_57 (0.000859)
# 396. feature nk_feat_147 (0.000858)
# 397. feature std_67 (0.000857)
# 398. feature median_6 (0.000857)
# 399. feature nk_feat_178 (0.000855)
# 400. feature mu_177 (0.000852)
# 401. feature nk_feat_45 (0.000851)
# 402. feature std_74 (0.000851)
# 403. feature mu_3 (0.000849)
# 404. feature nk_feat_53 (0.000848)
# 405. feature nk_feat_80 (0.000846)
# 406. feature mu_154 (0.000844)
# 407. feature nk_feat_12 (0.000843)
# 408. feature nk_feat_215 (0.000841)
# 409. feature std_158 (0.000841)
# 410. feature median_84 (0.000838)
# 411. feature std_174 (0.000838)
# 412. feature mu_159 (0.000836)
# 413. feature nk_feat_97 (0.000835)
# 414. feature nk_feat_221 (0.000834)
# 415. feature mu_131 (0.000833)
# 416. feature fft_q3_3 (0.000833)
# 417. feature mu_34 (0.000832)
# 418. feature mu_6 (0.000832)
# 419. feature nk_feat_228 (0.000831)
# 420. feature mu_65 (0.000831)
# 421. feature mu_174 (0.000830)
# 422. feature fft_mean_change_2 (0.000829)
# 423. feature median_87 (0.000829)
# 424. feature mu_156 (0.000827)
# 425. feature fft_q95_0 (0.000827)
# 426. feature mu_2 (0.000826)
# 427. feature mu_126 (0.000826)
# 428. feature std_58 (0.000826)
# 429. feature nk_feat_59 (0.000824)
# 430. feature std_56 (0.000824)
# 431. feature median_33 (0.000824)
# 432. feature nk_feat_225 (0.000824)
# 433. feature std_32 (0.000824)
# 434. feature std_40 (0.000821)
# 435. feature fft_mean_change_3 (0.000820)
# 436. feature std_87 (0.000820)
# 437. feature median_18 (0.000819)
# 438. feature fft_mean_1 (0.000819)
# 439. feature nk_feat_129 (0.000817)
# 440. feature std_28 (0.000817)
# 441. feature std_7 (0.000817)
# 442. feature fft_q5_2 (0.000815)
# 443. feature nk_feat_211 (0.000815)
# 444. feature std_37 (0.000815)
# 445. feature nk_feat_180 (0.000814)
# 446. feature median_49 (0.000814)
# 447. feature nk_feat_176 (0.000814)
# 448. feature std_26 (0.000813)
# 449. feature std_69 (0.000812)
# 450. feature median_32 (0.000812)
# 451. feature median_54 (0.000810)
# 452. feature std_168 (0.000810)
# 453. feature nk_feat_64 (0.000810)
# 454. feature fft_q95_2 (0.000810)
# 455. feature std_29 (0.000809)
# 456. feature mu_168 (0.000808)
# 457. feature nk_feat_75 (0.000807)
# 458. feature std_33 (0.000807)
# 459. feature nk_feat_165 (0.000806)
# 460. feature std_25 (0.000805)
# 461. feature fft_q90_0 (0.000804)
# 462. feature nk_feat_60 (0.000804)
# 463. feature mu_123 (0.000804)
# 464. feature std_131 (0.000802)
# 465. feature nk_feat_23 (0.000802)
# 466. feature fft_skew_0 (0.000801)
# 467. feature mu_82 (0.000801)
# 468. feature fft_min_3 (0.000801)
# 469. feature nk_feat_177 (0.000801)
# 470. feature mu_57 (0.000800)
# 471. feature median_21 (0.000800)
# 472. feature fft_skew_3 (0.000799)
# 473. feature median_85 (0.000797)
# 474. feature nk_feat_0 (0.000796)
# 475. feature nk_feat_112 (0.000795)
# 476. feature nk_feat_212 (0.000795)
# 477. feature mu_63 (0.000795)
# 478. feature std_80 (0.000794)
# 479. feature std_77 (0.000793)
# 480. feature fft_q5_3 (0.000793)
# 481. feature mu_164 (0.000793)
# 482. feature std_57 (0.000792)
# 483. feature std_54 (0.000791)
# 484. feature fft_q10_3 (0.000790)
# 485. feature fft_q5_0 (0.000789)
# 486. feature std_134 (0.000788)
# 487. feature median_2 (0.000786)
# 488. feature nk_feat_21 (0.000786)
# 489. feature std_24 (0.000786)
# 490. feature std_59 (0.000786)
# 491. feature median_124 (0.000786)
# 492. feature fft_q1_3 (0.000786)
# 493. feature median_4 (0.000786)
# 494. feature mu_86 (0.000785)
# 495. feature std_146 (0.000785)
# 496. feature std_70 (0.000785)
# 497. feature median_156 (0.000784)
# 498. feature std_110 (0.000784)
# 499. feature mu_122 (0.000783)
# 500. feature std_49 (0.000782)
# 501. feature mu_50 (0.000781)
# 502. feature nk_feat_210 (0.000780)
# 503. feature std_11 (0.000779)
# 504. feature nk_feat_11 (0.000779)
# 505. feature mu_58 (0.000779)
# 506. feature nk_feat_49 (0.000779)
# 507. feature std_68 (0.000778)
# 508. feature std_118 (0.000778)
# 509. feature std_48 (0.000776)
# 510. feature nk_feat_46 (0.000776)
# 511. feature median_169 (0.000775)
# 512. feature std_165 (0.000775)
# 513. feature median_129 (0.000775)
# 514. feature nk_feat_87 (0.000775)
# 515. feature median_50 (0.000774)
# 516. feature mu_64 (0.000774)
# 517. feature nk_feat_56 (0.000774)
# 518. feature median_0 (0.000773)
# 519. feature std_79 (0.000773)
# 520. feature mu_1 (0.000773)
# 521. feature mu_89 (0.000772)
# 522. feature nk_feat_48 (0.000770)
# 523. feature mu_31 (0.000770)
# 524. feature nk_feat_144 (0.000769)
# 525. feature nk_feat_223 (0.000767)
# 526. feature nk_feat_140 (0.000767)
# 527. feature mu_146 (0.000766)
# 528. feature nk_feat_61 (0.000765)
# 529. feature nk_feat_54 (0.000764)
# 530. feature mu_88 (0.000764)
# 531. feature std_0 (0.000764)
# 532. feature nk_feat_208 (0.000764)
# 533. feature nk_feat_166 (0.000764)
# 534. feature nk_feat_14 (0.000764)
# 535. feature std_45 (0.000763)
# 536. feature fft_q90_2 (0.000762)
# 537. feature median_154 (0.000762)
# 538. feature fft_median_3 (0.000762)
# 539. feature std_38 (0.000762)
# 540. feature std_137 (0.000762)
# 541. feature median_56 (0.000762)
# 542. feature mu_119 (0.000761)
# 543. feature mu_157 (0.000760)
# 544. feature mu_134 (0.000760)
# 545. feature median_63 (0.000759)
# 546. feature std_81 (0.000758)
# 547. feature mu_90 (0.000758)
# 548. feature std_91 (0.000757)
# 549. feature nk_feat_218 (0.000757)
# 550. feature nk_feat_82 (0.000754)
# 551. feature std_34 (0.000754)
# 552. feature fft_q90_3 (0.000754)
# 553. feature mu_55 (0.000752)
# 554. feature median_139 (0.000751)
# 555. feature std_41 (0.000751)
# 556. feature nk_feat_226 (0.000751)
# 557. feature fft_min_0 (0.000750)
# 558. feature nk_feat_222 (0.000749)
# 559. feature nk_feat_50 (0.000747)
# 560. feature mu_125 (0.000745)
# 561. feature std_82 (0.000744)
# 562. feature std_136 (0.000743)
# 563. feature median_136 (0.000742)
# 564. feature median_92 (0.000741)
# 565. feature fft_q3_0 (0.000741)
# 566. feature mu_0 (0.000741)
# 567. feature nk_feat_143 (0.000741)
# 568. feature std_132 (0.000741)
# 569. feature median_128 (0.000740)
# 570. feature fft_q10_0 (0.000740)
# 571. feature fft_mean_change_0 (0.000739)
# 572. feature mu_128 (0.000736)
# 573. feature std_39 (0.000735)
# 574. feature std_72 (0.000733)
# 575. feature std_145 (0.000732)
# 576. feature mu_19 (0.000732)
# 577. feature median_135 (0.000732)
# 578. feature mu_33 (0.000732)
# 579. feature std_16 (0.000731)
# 580. feature std_88 (0.000731)
# 581. feature median_53 (0.000731)
# 582. feature nk_feat_52 (0.000730)
# 583. feature median_95 (0.000729)
# 584. feature std_2 (0.000728)
# 585. feature mu_130 (0.000726)
# 586. feature std_78 (0.000725)
# 587. feature nk_feat_63 (0.000723)
# 588. feature std_6 (0.000723)
# 589. feature fft_q1_0 (0.000723)
# 590. feature median_30 (0.000722)
# 591. feature nk_feat_73 (0.000722)
# 592. feature std_167 (0.000722)
# 593. feature std_89 (0.000722)
# 594. feature nk_feat_51 (0.000721)
# 595. feature std_46 (0.000721)
# 596. feature std_9 (0.000720)
# 597. feature std_73 (0.000720)
# 598. feature std_143 (0.000718)
# 599. feature median_52 (0.000718)
# 600. feature std_5 (0.000717)
# 601. feature nk_feat_207 (0.000717)
# 602. feature std_8 (0.000717)
# 603. feature std_179 (0.000715)
# 604. feature std_147 (0.000715)
# 605. feature median_160 (0.000715)
# 606. feature median_88 (0.000713)
# 607. feature std_92 (0.000712)
# 608. feature std_12 (0.000712)
# 609. feature std_119 (0.000711)
# 610. feature mu_133 (0.000711)
# 611. feature mu_149 (0.000710)
# 612. feature nk_feat_137 (0.000709)
# 613. feature mu_171 (0.000708)
# 614. feature mu_54 (0.000708)
# 615. feature std_125 (0.000708)
# 616. feature median_159 (0.000707)
# 617. feature nk_feat_16 (0.000704)
# 618. feature mu_21 (0.000704)
# 619. feature std_3 (0.000703)
# 620. feature mu_151 (0.000703)
# 621. feature std_138 (0.000702)
# 622. feature median_64 (0.000702)
# 623. feature std_43 (0.000700)
# 624. feature std_154 (0.000694)
# 625. feature std_135 (0.000694)
# 626. feature nk_feat_148 (0.000691)
# 627. feature median_162 (0.000691)
# 628. feature std_128 (0.000690)
# 629. feature mu_172 (0.000688)
# 630. feature std_83 (0.000688)
# 631. feature std_105 (0.000687)
# 632. feature mu_29 (0.000687)
# 633. feature mu_22 (0.000686)
# 634. feature std_107 (0.000686)
# 635. feature std_129 (0.000686)
# 636. feature median_157 (0.000685)
# 637. feature median_25 (0.000683)
# 638. feature nk_feat_58 (0.000683)
# 639. feature mu_32 (0.000682)
# 640. feature mu_26 (0.000681)
# 641. feature std_75 (0.000680)
# 642. feature std_100 (0.000679)
# 643. feature median_55 (0.000679)
# 644. feature std_31 (0.000677)
# 645. feature nk_feat_13 (0.000676)
# 646. feature std_106 (0.000676)
# 647. feature nk_feat_217 (0.000675)
# 648. feature mu_158 (0.000673)
# 649. feature mu_51 (0.000672)
# 650. feature std_97 (0.000671)
# 651. feature std_130 (0.000670)
# 652. feature std_36 (0.000670)
# 653. feature mu_25 (0.000670)
# 654. feature nk_feat_19 (0.000669)
# 655. feature median_137 (0.000668)
# 656. feature mu_20 (0.000666)
# 657. feature std_93 (0.000666)
# 658. feature median_89 (0.000666)
# 659. feature std_61 (0.000665)
# 660. feature nk_feat_146 (0.000665)
# 661. feature nk_feat_62 (0.000663)
# 662. feature median_140 (0.000663)
# 663. feature std_101 (0.000661)
# 664. feature nk_feat_204 (0.000660)
# 665. feature mu_91 (0.000660)
# 666. feature std_108 (0.000660)
# 667. feature nk_feat_209 (0.000660)
# 668. feature mu_120 (0.000660)
# 669. feature nk_feat_29 (0.000659)
# 670. feature mu_95 (0.000658)
# 671. feature median_142 (0.000658)
# 672. feature median_31 (0.000658)
# 673. feature median_130 (0.000657)
# 674. feature mu_124 (0.000657)
# 675. feature mu_167 (0.000656)
# 676. feature std_149 (0.000656)
# 677. feature mu_135 (0.000655)
# 678. feature median_126 (0.000655)
# 679. feature fft_std_3 (0.000654)
# 680. feature fft_iqr_3 (0.000654)
# 681. feature std_47 (0.000654)
# 682. feature median_161 (0.000654)
# 683. feature std_115 (0.000654)
# 684. feature median_122 (0.000653)
# 685. feature std_116 (0.000653)
# 686. feature nk_feat_17 (0.000652)
# 687. feature mu_121 (0.000652)
# 688. feature median_134 (0.000651)
# 689. feature mu_148 (0.000650)
# 690. feature median_146 (0.000650)
# 691. feature median_96 (0.000648)
# 692. feature median_145 (0.000647)
# 693. feature median_133 (0.000647)
# 694. feature median_144 (0.000647)
# 695. feature std_113 (0.000646)
# 696. feature mu_138 (0.000646)
# 697. feature fft_max_3 (0.000645)
# 698. feature std_86 (0.000642)
# 699. feature fft_iqr_0 (0.000641)
# 700. feature std_99 (0.000641)
# 701. feature mu_118 (0.000640)
# 702. feature std_123 (0.000637)
# 703. feature std_104 (0.000636)
# 704. feature median_147 (0.000636)
# 705. feature std_103 (0.000632)
# 706. feature median_172 (0.000632)
# 707. feature median_125 (0.000631)
# 708. feature median_166 (0.000630)
# 709. feature mu_150 (0.000629)
# 710. feature nk_feat_115 (0.000629)
# 711. feature median_111 (0.000629)
# 712. feature mu_160 (0.000629)
# 713. feature mu_93 (0.000628)
# 714. feature mu_170 (0.000627)
# 715. feature mu_24 (0.000627)
# 716. feature mu_152 (0.000625)
# 717. feature mu_28 (0.000623)
# 718. feature median_153 (0.000623)
# 719. feature fft_kurtosis_0 (0.000622)
# 720. feature nk_feat_93 (0.000619)
# 721. feature median_29 (0.000616)
# 722. feature std_121 (0.000616)
# 723. feature median_171 (0.000614)
# 724. feature mu_136 (0.000614)
# 725. feature mu_92 (0.000613)
# 726. feature median_23 (0.000613)
# 727. feature std_120 (0.000611)
# 728. feature mu_145 (0.000611)
# 729. feature mu_162 (0.000611)
# 730. feature median_167 (0.000609)
# 731. feature mu_112 (0.000607)
# 732. feature median_152 (0.000606)
# 733. feature mu_23 (0.000605)
# 734. feature mu_141 (0.000605)
# 735. feature median_143 (0.000605)
# 736. feature median_24 (0.000604)
# 737. feature median_116 (0.000602)
# 738. feature std_126 (0.000601)
# 739. feature std_114 (0.000599)
# 740. feature median_151 (0.000598)
# 741. feature median_112 (0.000596)
# 742. feature median_22 (0.000594)
# 743. feature std_127 (0.000593)
# 744. feature mu_155 (0.000592)
# 745. feature std_50 (0.000591)
# 746. feature median_131 (0.000590)
# 747. feature std_117 (0.000589)
# 748. feature mu_96 (0.000588)
# 749. feature median_155 (0.000587)
# 750. feature median_165 (0.000586)
# 751. feature median_123 (0.000585)
# 752. feature median_148 (0.000583)
# 753. feature median_109 (0.000583)
# 754. feature std_30 (0.000581)
# 755. feature mu_142 (0.000581)
# 756. feature mu_161 (0.000576)
# 757. feature std_90 (0.000573)
# 758. feature mu_144 (0.000573)
# 759. feature median_158 (0.000570)
# 760. feature nk_feat_20 (0.000570)
# 761. feature median_90 (0.000570)
# 762. feature mu_139 (0.000568)
# 763. feature mu_163 (0.000567)
# 764. feature median_163 (0.000567)
# 765. feature median_150 (0.000566)
# 766. feature std_109 (0.000565)
# 767. feature median_93 (0.000565)
# 768. feature median_138 (0.000564)
# 769. feature mu_30 (0.000564)
# 770. feature mu_153 (0.000564)
# 771. feature mu_104 (0.000563)
# 772. feature median_115 (0.000563)
# 773. feature median_164 (0.000561)
# 774. feature median_28 (0.000557)
# 775. feature std_85 (0.000557)
# 776. feature mu_147 (0.000556)
# 777. feature mu_143 (0.000554)
# 778. feature std_111 (0.000553)
# 779. feature median_94 (0.000551)
# 780. feature median_149 (0.000547)
# 781. feature median_27 (0.000545)
# 782. feature median_26 (0.000544)
# 783. feature mu_97 (0.000544)
# 784. feature mu_107 (0.000544)
# 785. feature std_94 (0.000544)
# 786. feature median_110 (0.000543)
# 787. feature median_170 (0.000541)
# 788. feature median_107 (0.000540)
# 789. feature mu_99 (0.000539)
# 790. feature median_114 (0.000539)
# 791. feature mu_169 (0.000536)
# 792. feature mu_117 (0.000535)
# 793. feature median_119 (0.000533)
# 794. feature median_108 (0.000533)
# 795. feature median_102 (0.000531)
# 796. feature mu_140 (0.000530)
# 797. feature median_121 (0.000530)
# 798. feature mu_166 (0.000530)
# 799. feature median_91 (0.000529)
# 800. feature median_168 (0.000526)
# 801. feature mu_27 (0.000525)
# 802. feature std_124 (0.000520)
# 803. feature median_141 (0.000519)
# 804. feature std_95 (0.000518)
# 805. feature median_99 (0.000517)
# 806. feature mu_137 (0.000515)
# 807. feature median_97 (0.000514)
# 808. feature mu_101 (0.000511)
# 809. feature mu_98 (0.000508)
# 810. feature mu_105 (0.000506)
# 811. feature median_118 (0.000504)
# 812. feature fft_q90_1 (0.000502)
# 813. feature std_112 (0.000502)
# 814. feature mu_113 (0.000500)
# 815. feature mu_111 (0.000500)
# 816. feature median_101 (0.000500)
# 817. feature fft_q1_1 (0.000499)
# 818. feature mu_114 (0.000499)
# 819. feature mu_109 (0.000498)
# 820. feature mu_108 (0.000492)
# 821. feature mu_165 (0.000492)
# 822. feature fft_q95_1 (0.000491)
# 823. feature mu_103 (0.000488)
# 824. feature median_120 (0.000480)
# 825. feature fft_q5_1 (0.000476)
# 826. feature median_100 (0.000475)
# 827. feature mu_116 (0.000474)
# 828. feature std_98 (0.000473)
# 829. feature mu_100 (0.000469)
# 830. feature median_98 (0.000466)
# 831. feature mu_110 (0.000465)
# 832. feature mu_106 (0.000464)
# 833. feature median_106 (0.000459)
# 834. feature std_96 (0.000456)
# 835. feature std_102 (0.000454)
# 836. feature median_117 (0.000453)
# 837. feature median_105 (0.000449)
# 838. feature median_103 (0.000446)
# 839. feature mu_115 (0.000446)
# 840. feature std_122 (0.000443)
# 841. feature mu_94 (0.000442)
# 842. feature median_104 (0.000440)
# 843. feature median_113 (0.000425)
# 844. feature mu_102 (0.000416)
# 845. feature fft_q3_1 (0.000380)
# 846. feature fft_skew_1 (0.000221)
# 847. feature fft_std_1 (0.000196)
# 848. feature fft_kurtosis_1 (0.000190)
# 849. feature fft_iqr_1 (0.000177)
# 850. feature fft_mean_2 (0.000000)

# %%
import pickle
filename = 'models/random_forest_model.sav'
pickle.dump(clf, open(filename, 'wb'))

# %%
y_test = clf.predict(x_test)
data_y_test = {
    'id': [i for i in range(len(y_test))],
    'y': y_test
}
df_y_test = pd.DataFrame(data_y_test)
df_y_test.to_csv('outputs/output_random_forest.csv', index=False)

# %%
#obtain validation set
x_train_2, x_val, y_train_2, y_val = train_test_split(x_train, y_train, test_size=0.2, random_state=42)
clf.fit(x_train_2, np.ravel(y_train_2))
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
from sklearn import metrics
y_pred = clf.predict(x_val)
cm = metrics.confusion_matrix(y_val, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=clf.classes_)
disp.plot()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [71], line 3
#       1 #obtain validation set
#       2 x_train_2, x_val, y_train_2, y_val = train_test_split(x_train, y_train, test_size=0.2, random_state=42)
# ----> 3 clf.fit(x_train_2, np.ravel(y_train_2))
#       4 from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
#       5 from sklearn import metrics
#
# File ~/Scaricati/AML_Pr_2/venv/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:476, in BaseForest.fit(self, X, y, sample_weight)
#     465 trees = [
#     466     self._make_estimator(append=False, random_state=random_state)
#     467     for i in range(n_more_estimators)
#     468 ]
#     470 # Parallel loop: we prefer the threading backend as the Cython code
#     471 # for fitting the trees is internally releasing the Python GIL
#     472 # making threading more efficient than multiprocessing in
#     473 # that case. However, for joblib 0.12+ we respect any
#     474 # parallel_backend contexts set at a higher level,
#     475 # since correctness does not rely on using threads.
# --> 476 trees = Parallel(
#     477     n_jobs=self.n_jobs,
#     478     verbose=self.verbose,
#     479     prefer="threads",
#     480 )(
#     481     delayed(_parallel_build_trees)(
#     482         t,
#     483         self.bootstrap,
#     484         X,
#     485         y,
#     486         sample_weight,
#     487         i,
#     488         len(trees),
#     489         verbose=self.verbose,
#     490         class_weight=self.class_weight,
#     491         n_samples_bootstrap=n_samples_bootstrap,
#     492     )
#     493     for i, t in enumerate(trees)
#     494 )
#     496 # Collect newly grown trees
#     497 self.estimators_.extend(trees)
#
# File ~/Scaricati/AML_Pr_2/venv/lib/python3.8/site-packages/joblib/parallel.py:1088, in Parallel.__call__(self, iterable)
#    1085 if self.dispatch_one_batch(iterator):
#    1086     self._iterating = self._original_iterator is not None
# -> 1088 while self.dispatch_one_batch(iterator):
#    1089     pass
#    1091 if pre_dispatch == "all" or n_jobs == 1:
#    1092     # The iterable was consumed all at once by the above for loop.
#    1093     # No need to wait for async callbacks to trigger to
#    1094     # consumption.
#
# File ~/Scaricati/AML_Pr_2/venv/lib/python3.8/site-packages/joblib/parallel.py:901, in Parallel.dispatch_one_batch(self, iterator)
#     899     return False
#     900 else:
# --> 901     self._dispatch(tasks)
#     902     return True
#
# File ~/Scaricati/AML_Pr_2/venv/lib/python3.8/site-packages/joblib/parallel.py:819, in Parallel._dispatch(self, batch)
#     817 with self._lock:
#     818     job_idx = len(self._jobs)
# --> 819     job = self._backend.apply_async(batch, callback=cb)
#     820     # A job can complete so quickly than its callback is
#     821     # called before we get here, causing self._jobs to
#     822     # grow. To ensure correct results ordering, .insert is
#     823     # used (rather than .append) in the following line
#     824     self._jobs.insert(job_idx, job)
#
# File ~/Scaricati/AML_Pr_2/venv/lib/python3.8/site-packages/joblib/_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File ~/Scaricati/AML_Pr_2/venv/lib/python3.8/site-packages/joblib/_parallel_backends.py:597, in ImmediateResult.__init__(self, batch)
#     594 def __init__(self, batch):
#     595     # Don't delay the application, to avoid keeping the input
#     596     # arguments in memory
# --> 597     self.results = batch()
#
# File ~/Scaricati/AML_Pr_2/venv/lib/python3.8/site-packages/joblib/parallel.py:288, in BatchedCalls.__call__(self)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File ~/Scaricati/AML_Pr_2/venv/lib/python3.8/site-packages/joblib/parallel.py:288, in <listcomp>(.0)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File ~/Scaricati/AML_Pr_2/venv/lib/python3.8/site-packages/sklearn/utils/fixes.py:117, in _FuncWrapper.__call__(self, *args, **kwargs)
#     115 def __call__(self, *args, **kwargs):
#     116     with config_context(**self.config):
# --> 117         return self.function(*args, **kwargs)
#
# File ~/Scaricati/AML_Pr_2/venv/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:189, in _parallel_build_trees(tree, bootstrap, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap)
#     186     elif class_weight == "balanced_subsample":
#     187         curr_sample_weight *= compute_sample_weight("balanced", y, indices=indices)
# --> 189     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#     190 else:
#     191     tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#
# File ~/Scaricati/AML_Pr_2/venv/lib/python3.8/site-packages/sklearn/tree/_classes.py:969, in DecisionTreeClassifier.fit(self, X, y, sample_weight, check_input)
#     939 def fit(self, X, y, sample_weight=None, check_input=True):
#     940     """Build a decision tree classifier from the training set (X, y).
#     941
#     942     Parameters
#    (...)
#     966         Fitted estimator.
#     967     """
# --> 969     super().fit(
#     970         X,
#     971         y,
#     972         sample_weight=sample_weight,
#     973         check_input=check_input,
#     974     )
#     975     return self
#
# File ~/Scaricati/AML_Pr_2/venv/lib/python3.8/site-packages/sklearn/tree/_classes.py:458, in BaseDecisionTree.fit(self, X, y, sample_weight, check_input)
#     447 else:
#     448     builder = BestFirstTreeBuilder(
#     449         splitter,
#     450         min_samples_split,
#    (...)
#     455         self.min_impurity_decrease,
#     456     )
# --> 458 builder.build(self.tree_, X, y, sample_weight)
#     460 if self.n_outputs_ == 1 and is_classifier(self):
#     461     self.n_classes_ = self.n_classes_[0]
#
# KeyboardInterrupt:
